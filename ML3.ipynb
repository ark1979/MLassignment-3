# %% [markdown]
# # ML-assignment 3

# %% [markdown]
# ## Part 0
#
# ### Hand in a few paragraphs with some more thoughts on possible business cases.
# * One business case could be to get statistics of customers calling to the customer service of any given type of company. Knowing your customers is also useful and knowing the gender balance of people calling the company might be useful knowledge in order to improve efficiency and service.
# * Detecting gender based on voice data might help to enforce gender exclusivity. Ex dating sites.
# * In general gender detection by voice is useful for when doing gender related studies. An example could be a workplace trying that wants to know much male/female employees participate verbally during work meetings. Another example could be to examine to study how big percentage of time male/female characters talk during movies or TV-shows.
#
# ### Could we treat streaming data with these simple models only adding a bit of data preprocessing from audio streams?
# * With the proper data preprocessing it would be possible to apply the machine learning model to a live data strem. As log as we are able to extract the chosen features. We would probably have to extract only the latest small part (maybe 1 second) of the data in order to identify the gender of the person currently talking. However this would probably only work with one person talking at a time.

# %% [markdown]
# # Part 1

# %%
# %pylab inline
import pandas as pd
import seaborn as sns
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data_url = "https://raw.githubusercontent.com/OnkelDunkel/MLAssignment2/master/voice.csv"
df = pd.read_csv(data_url)

# %%
df.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0  0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1  0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2  0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3  0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4  0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
#
#           kurt    sp.ent       sfm  ...  centroid   meanfun    minfun  \
# 0   274.402906  0.893369  0.491918  ...  0.059781  0.084279  0.015702
# 1   634.613855  0.892193  0.513724  ...  0.066009  0.107937  0.015826
# 2  1024.927705  0.846389  0.478905  ...  0.077316  0.098706  0.015656
# 3     4.177296  0.963322  0.727232  ...  0.151228  0.088965  0.017798
# 4     4.333713  0.971955  0.783568  ...  0.135120  0.106398  0.016931
#
#      maxfun   meandom    mindom    maxdom   dfrange   modindx  label
# ...

# %% [markdown]
# ### Do we see correlations in feature space?
# The below diagram shows the correlation between the features. When to features have high correlation it means that one affect the other positively, meaning if one goes up the second one follows. Correlations closer to 0 means that there are less of a link between them, if one increases the second one might increase but we don't know.
#
# Below is a plot of the correlation between the data:

# %%
fig, ax = plt.subplots(figsize=(15,11))
sns.heatmap(df.corr().round(2),linewidths=0.50,vmax=1.0, square=True, cmap="Blues", linecolor='black', annot=True, ax=ax)

# %% [markdown]
# We saw that some of the features had close to white colors in the heatmap showcasing a negative correlation. When features are negatively correlated it doesn't mean that there are no relation between them. However it means that when one feature increases the second feature decreases. So a negative correlation can imply that there is a relation between the features.
#
# Below is a heatmap of the correlation between the features where all values are converted into absolute values:

# %%
fig, ax = plt.subplots(figsize=(15,11))
sns.heatmap(df.corr().abs().round(2),linewidths=0.50,vmax=1.0, square=True, cmap="Blues", linecolor='black', annot=True, ax=ax)

# %% [markdown]
# With this heatmap we aim to show the features that might have a relation to one another so we do not distinquish between negative and positive correlation. If a feature have a small absolute correlation to other features it can either mean that the feature does not say a lot about the data or that the feature brings a new perspective on the table.

# %% [markdown]
# We checked whether there were any null values which there wasn't.

# %%
df.isnull().any()
# Out:
# meanfreq    False
# sd          False
# median      False
# Q25         False
# Q75         False
# IQR         False
# skew        False
# kurt        False
# sp.ent      False
# sfm         False
# mode        False
# centroid    False
# meanfun     False
# minfun      False
# maxfun      False
# meandom     False
# mindom      False
# maxdom      False
# dfrange     False
# modindx     False
# label       False
# dtype: bool

# %% [markdown]
# We converted the labels into binary (female = 1, male = 0). And we check the distribution of values for the output label.

# %%
df.label = np.where(df.label.values == 'female', 1, 0)
df.label.value_counts()
# Out:
# 1    1584
# 0    1584
# Name: label, dtype: int64

# %% [markdown]
# ### Feature removal
# In the heat maps we saw that the centroid and the mean frequency have a correlation of 1. We thought this was strange and after examining the data we saw that the 2 columns contained completely duplicate data. We therefore decided to remove the centroid from our dataset in order to save on performance by having one less feature.

# %%
X = df.drop(['label', 'centroid'], axis = 1)
Y = df.label

# %% [markdown]
# # Part 2: Model construction

# %% [markdown]
# ## Part 2.1: k-Nearest Neighbours
# We create the KNN with the following parameters:
# * n_neighbours = 5:
# * weights = uniform: This means that the distance from the data point to the nearest neighbours doesn't make a difference change the importance weight of the neighbour. The reason we don't want this is because that our training data might contain outliers and we don't want single outliers to have a high impact on the classification.
# * algorithm = :
# * leaf_size = :

# %%
knn = make_pipeline
(
    StandardScaler(), 
    KNeighborsClassifier
    (
        n_neighbors=5,
        weights="uniform",
        algorithm="auto",
        leaf_size,
        p
        metric
        metric_params
        n_jobs
    )
)
